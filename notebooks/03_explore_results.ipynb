# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.evaluation import build_results_df


results_df = build_results_df(
    results_path=Path.cwd().parent / "results" / "default_experiment" / "evidential" / "seed-42_fn-2_nz-2_tri-[-1, 1]_tei-[-4, 4]_trn-5000x1_grid-1000_model-evidential" / "250927_2317",
    metrics=["mae", "mse", "rmse", "nll_total", "ence_total", "spearman_aleatoric", "train_time_mean", "infer_time_mean"],
)
results_df
# Out:
#   cfg.experiment_name  cfg.model_runs  cfg.random_seed  \
# 0  default_experiment               1               42
#
#                                         cfg.function cfg.train_interval  \
# 0  [f_non_linear_2_features, sigma_non_linear_2_f...            [-1, 1]
#
#    cfg.train_instances  cfg.train_repeats cfg.test_interval  \
# 0                 5000                  1           [-4, 4]
#
#    cfg.test_grid_length cfg.model_name  ... cfg.model_params.target_dim  \
# 0                  1000     evidential  ...                           1
#
#   cfg.model_params.coeff       mae      rmse       mse  nll_total  ence_total  \
# 0                   0.01  2.807413  3.662034  13.41049   3.440979    0.924919
#
#    spearman_aleatoric train_time_mean  infer_time_mean
# 0            0.238704       18.685396         0.246469
#
# [1 rows x 29 columns]
