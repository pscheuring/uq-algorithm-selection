# %%
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np

project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.constants import STYLE_PATH, SUMMARY_PATH
from src.data_sampler import (
    f_cosine_hc2_1_feat,
    sigma_cubic_hc2_1_feat,
)
from src.evaluation import build_eval_dataframe
from src.utils.utils_results import load_meta_model_benchmarking_results
from src.visualizations.plot_dgp import plot_true_variance_grid, sample_and_plot_true
from src.visualizations.figure_saver import NotebookFigureSaver
from src.visualizations.plot_metrics import plot_metrics_grid_exp1
from src.visualizations.plot_uq_multi import plot_uq_multi

plt.style.use(STYLE_PATH)

# %%
FigureSaver = NotebookFigureSaver(chapter_id="01_exp1_n_unique")
eval_df = build_eval_dataframe(SUMMARY_PATH)
eval_df_exp1 = eval_df[eval_df["experiment_name"] == "exp1_n_unique"]

# %%
bbb_instances_40 = load_meta_model_benchmarking_results("exp1_n_unique/bbb/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-40x0_grid-1000_model-bbb/251031_1825")
bbb_instances_200 = load_meta_model_benchmarking_results("exp1_n_unique/bbb/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-200x0_grid-1000_model-bbb/251031_1825")
bbb_instances_1000 = load_meta_model_benchmarking_results("exp1_n_unique/bbb/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-1000x0_grid-1000_model-bbb/251031_1826")
bbb_instances_5000 = load_meta_model_benchmarking_results("exp1_n_unique/bbb/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-5000x0_grid-1000_model-bbb/251031_1829")
bbb_instances_25000 = load_meta_model_benchmarking_results("exp1_n_unique/bbb/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-25000x0_grid-1000_model-bbb/251031_1844")
bbb_instances_100000 = load_meta_model_benchmarking_results("exp1_n_unique/bbb/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-100000x0_grid-1000_model-bbb/251031_1947")

mcdropout_instances_40 = load_meta_model_benchmarking_results("exp1_n_unique/mcdropout/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-40x0_grid-1000_model-mcdropout/251031_1825")    
mcdropout_instances_200 = load_meta_model_benchmarking_results("exp1_n_unique/mcdropout/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-200x0_grid-1000_model-mcdropout/251031_1825")
mcdropout_instances_1000 = load_meta_model_benchmarking_results("exp1_n_unique/mcdropout/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-1000x0_grid-1000_model-mcdropout/251031_1826")
mcdropout_instances_5000 = load_meta_model_benchmarking_results("exp1_n_unique/mcdropout/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-5000x0_grid-1000_model-mcdropout/251031_1827")
mcdropout_instances_25000 = load_meta_model_benchmarking_results("exp1_n_unique/mcdropout/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-25000x0_grid-1000_model-mcdropout/251031_1836")
mcdropout_instances_100000 = load_meta_model_benchmarking_results("exp1_n_unique/mcdropout/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-100000x0_grid-1000_model-mcdropout/251031_1914")

ensemble_instances_40 = load_meta_model_benchmarking_results("exp1_n_unique/ensemble/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-40x0_grid-1000_model-ensemble/251031_1825")
ensemble_instances_200 = load_meta_model_benchmarking_results("exp1_n_unique/ensemble/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-200x0_grid-1000_model-ensemble/251031_1825")
ensemble_instances_1000 = load_meta_model_benchmarking_results("exp1_n_unique/ensemble/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-1000x0_grid-1000_model-ensemble/251031_1827")
ensemble_instances_5000 = load_meta_model_benchmarking_results("exp1_n_unique/ensemble/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-5000x0_grid-1000_model-ensemble/251031_1833")
ensemble_instances_25000 = load_meta_model_benchmarking_results("exp1_n_unique/ensemble/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-25000x0_grid-1000_model-ensemble/251031_1904")
ensemble_instances_100000 = load_meta_model_benchmarking_results("exp1_n_unique/ensemble/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-100000x0_grid-1000_model-ensemble/251031_2219")

evidential_instances_40 = load_meta_model_benchmarking_results("exp1_n_unique/evidential/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-40x0_grid-1000_model-evidential/251031_1825")
evidential_instances_200 = load_meta_model_benchmarking_results("exp1_n_unique/evidential/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-200x0_grid-1000_model-evidential/251031_1825")
evidential_instances_1000 = load_meta_model_benchmarking_results("exp1_n_unique/evidential/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-1000x0_grid-1000_model-evidential/251031_1826")
evidential_instances_5000 = load_meta_model_benchmarking_results("exp1_n_unique/evidential/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-5000x0_grid-1000_model-evidential/251031_1828")
evidential_instances_25000 = load_meta_model_benchmarking_results("exp1_n_unique/evidential/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-25000x0_grid-1000_model-evidential/251031_1839")
evidential_instances_100000 = load_meta_model_benchmarking_results("exp1_n_unique/evidential/seed-42_fn-1_nz-1_tri-[-4.0, 4.0]_tei-[-6.0, 6.0]_trn-100000x0_grid-1000_model-evidential/251031_1925")

# %%
fig, ax = sample_and_plot_true(
    n_points=1000,
    train_repeats=0,
    seed=42,
    f_true=f_cosine_hc2_1_feat,
    sigma_true=sigma_cubic_hc2_1_feat,
    figsize=(20, 6),
    ood_bounds=(-4, 4),
)
FigureSaver.save_fig(fig, "exp1_dgp")
# Out:
# Saved: /Users/scheuringp/Coding/uq-algorithm-selection/images/01_exp1_n_unique/exp1_dgp.png
# Saved: /Users/scheuringp/Coding/uq-algorithm-selection/images/01_exp1_n_unique/exp1_dgp.pdf

# %%
configs = [
    {
        "f_true": f_cosine_hc2_1_feat,
        "sigma_true": sigma_cubic_hc2_1_feat,
        "n_points": 1000,
        "train_repeats": 0,
        "ood_bounds": (-4, 4),
        "title": "Experiment 1",
    },
    {
        "f_true": f_cosine_hc2_1_feat,
        "sigma_true": sigma_cubic_hc2_1_feat,
        "n_points": 40,
        "train_repeats": 5,
        "ood_bounds": (-4, 4),
        "title": "Experiment 2",
    },
    {
        "f_true": f_cosine_hc2_1_feat,
        "sigma_true": sigma_cubic_hc2_1_feat,
        "n_points": 1000,
        "train_repeats": 0,
        "ood_bounds": [[-4, -1], [1, 4]],
        "title": "Experiment 3",
    },
]

fig, leg = plot_true_variance_grid(
    configs,
    figsize=(20, 8),
    seed=42,
)

FigureSaver.save_fig(fig, "exp1_3_dgp")
# Out:
# Saved: /Users/scheuringp/Coding/uq-algorithm-selection/images/01_exp1_n_unique/exp1_3_dgp.png
# Saved: /Users/scheuringp/Coding/uq-algorithm-selection/images/01_exp1_n_unique/exp1_3_dgp.pdf

# %%
fig, leg = plot_uq_multi( 
    bbb_instances_1000,
    mcdropout_instances_1000,
    ensemble_instances_1000,
    evidential_instances_1000,
    labels=["Bayes by Backprop", "MC Dropout", "Deep Ensemble", "DER"],
    ood_bounds=[(-np.inf, -4), (4, np.inf)],
    x_min=-6, x_max=6,
    y_limits={
    "aleatoric": (0.0, 0.00075),
    "prediction": (0.8, 1.0),
    },
    y_logscale={
        "aleatoric": False, 
        "epistemic": True,
        "prediction": False,
    },
    show_runs=True,
    figsize=(20, 6),
    model_colors=["tab:olive", "tab:purple", "tab:brown", "tab:pink"],
)
FigureSaver.save_fig(fig, "exp1_model_comparison", bbox_extra_artists=(leg,))
# Out:
# Saved: /Users/scheuringp/Coding/uq-algorithm-selection/images/01_exp1_n_unique/exp1_model_comparison.png
# Saved: /Users/scheuringp/Coding/uq-algorithm-selection/images/01_exp1_n_unique/exp1_model_comparison.pdf

# %%
fig, leg = plot_uq_multi( 
    bbb_instances_40, 
    bbb_instances_1000, 
    bbb_instances_100000,
    labels = [r"$N_{\text{unique}}=40$", r"$N_{\text{unique}}=1{,}000$", r"$N_{\text{unique}}=100{,}000$"],
    ood_bounds=[(-np.inf, -4), (4, np.inf)],
    x_min=-6, x_max=6,
    y_limits={
    "prediction": (0.8, 1.0),
    },
    y_logscale={
        "aleatoric": True, 
        "epistemic": True,
        "prediction": False,
    },
    show_runs=True,
    figsize=(20, 6),
    model_colors=["tab:blue", "tab:red", "tab:green"],
)
FigureSaver.save_fig(fig, "exp1_bbb")
# Out:
# Saved: /Users/scheuringp/Coding/uq-algorithm-selection/images/01_exp1_n_unique/exp1_bbb.png
# Saved: /Users/scheuringp/Coding/uq-algorithm-selection/images/01_exp1_n_unique/exp1_bbb.pdf

# %%
fig, leg = plot_uq_multi( 
    ensemble_instances_40,
    ensemble_instances_1000,
    ensemble_instances_100000,
    labels = [r"$N_{\text{unique}}=40$", r"$N_{\text{unique}}=1{,}000$", r"$N_{\text{unique}}=100{,}000$"],
    ood_bounds=[(-np.inf, -4), (4, np.inf)],
    x_min=-6, x_max=6,
    y_limits={
    "prediction": (0.8, 1.0),
    },
    y_logscale={
        "aleatoric": False, 
        "epistemic": True,
        "prediction": False,
    },
    show_runs=True,
    figsize=(20, 6),
    model_colors=["tab:blue", "tab:red", "tab:green"],
)
FigureSaver.save_fig(fig, "exp1_ensemble")
# Out:
# Saved: /Users/scheuringp/Coding/uq-algorithm-selection/images/01_exp1_n_unique/exp1_ensemble.png
# Saved: /Users/scheuringp/Coding/uq-algorithm-selection/images/01_exp1_n_unique/exp1_ensemble.pdf

# %%
fig, leg = plot_uq_multi( 
    mcdropout_instances_40,
    mcdropout_instances_1000,
    mcdropout_instances_100000,
    labels = [r"$N_{\text{unique}}=40$", r"$N_{\text{unique}}=1{,}000$", r"$N_{\text{unique}}=100{,}000$"],
    ood_bounds=[(-np.inf, -4), (4, np.inf)],
    x_min=-6, x_max=6,
    y_limits={
    "prediction": (0.8, 1.0),
    },
    y_logscale={
        "aleatoric": False, 
        "epistemic": True,
        "prediction": False,
    },
    show_runs=True,
    figsize=(20, 6),
    model_colors=["tab:blue", "tab:red", "tab:green"],
)
FigureSaver.save_fig(fig, "exp1_mcdropout")
# Out:
# Saved: /Users/scheuringp/Coding/uq-algorithm-selection/images/01_exp1_n_unique/exp1_mcdropout.png
# Saved: /Users/scheuringp/Coding/uq-algorithm-selection/images/01_exp1_n_unique/exp1_mcdropout.pdf

# %%
fig, leg = plot_uq_multi( 
    evidential_instances_40,
    evidential_instances_1000,
    evidential_instances_100000,
    labels = [r"$N_{\text{unique}}=40$", r"$N_{\text{unique}}=1{,}000$", r"$N_{\text{unique}}=100{,}000$"],
    ood_bounds=[(-np.inf, -4), (4, np.inf)],
    x_min=-6, x_max=6,
    y_limits={
    "prediction": (0.8, 1.0),
    },
    y_logscale={
        "aleatoric": False, 
        "epistemic": True,
        "prediction": False,
    },
    show_runs=True,
    figsize=(20, 6),
    model_colors=["tab:blue", "tab:red", "tab:green"],
)
FigureSaver.save_fig(fig, "exp1_evidential")
# Out:
# Saved: /Users/scheuringp/Coding/uq-algorithm-selection/images/01_exp1_n_unique/exp1_evidential.png
# Saved: /Users/scheuringp/Coding/uq-algorithm-selection/images/01_exp1_n_unique/exp1_evidential.pdf

# %%
fig, leg = plot_metrics_grid_exp1(
    df_metrics=eval_df_exp1,
    model_col="model_name",
    config_col="train_instances",
    metric_bases=("nll_id", "mae_aleatoric", "auroc_ood"),
    mean_suffix="_median",
    bottom_titles=(
        "↓ NLL (ID)",                   # lower is better
        "↓ MAE aleatoric uncertainty",  # lower is better
        "↑ AUROC OOD",                  # higher is better
    ),
    figsize=(20, 6),
)

FigureSaver.save_fig(fig, "exp1_metrics")
# Out:
# /Users/scheuringp/Coding/uq-algorithm-selection/src/visualizations/plot_metrics.py:311: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0.15, 1, 1])
# Saved: /Users/scheuringp/Coding/uq-algorithm-selection/images/01_exp1_n_unique/exp1_metrics.png
# Saved: /Users/scheuringp/Coding/uq-algorithm-selection/images/01_exp1_n_unique/exp1_metrics.pdf
