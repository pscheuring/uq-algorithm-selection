# %%
import copy
import itertools
import sys
from pathlib import Path

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.utils.utils_data import create_train_test_data
from src.utils.utils_models import build_model
from src.utils.utils_pipeline import set_global_seed

# %%
BASE_JOB = {
    "experiment_name": "hyperparameter_tuning",
    "model_runs": 1,
    "seed": 42,
    "function": ["f_cosine_hc2_1_feat", "sigma_cubic_hc2_1_feat"],
    "train_interval": [-4.0, 4.0],
    "train_instances": 1100, # 100 for hyperparameter tuning
    "train_repeats": 0,
    "test_interval": [-6.0, 6.0],
    "test_grid_length": 1000,
    "test_add_points": None, # not needed for hyperparameter tuning
    "model_name": None, # filled by specific model
    "model_params": {
        "hidden_features": [64, 64],
        "activations": ["relu", "relu"],
        "weight_decay": 0.0,
        "p_drop": 0.0,
        "shuffle": True,
        "device": "cpu",
        "target_dim": 1,
        }
}

def make_job(base_job: dict, model_name: str, model_params: dict) -> dict:
    """
    Creates a new job dictionary based on a shared base job configuration.
    Merges BASE_JOB['model_params'] with model-specific params (model_params overrides).
    """
    job = copy.deepcopy(base_job)
    job["model_name"] = model_name

    # Merge: base defaults first, then model-specific overrides
    merged_params = copy.deepcopy(base_job["model_params"])
    merged_params.update(copy.deepcopy(model_params))
    job["model_params"] = merged_params
    return job



def grid_search(job: dict, param_grid: dict, train_size: int, val_size: int):
    """Runs grid search over specified hyperparameters.

    Args:
      job: config dict.
      param_grid: parameter grid to test.

    Returns:
      results_df: pd.DataFrame with one row per hyperparameter combo and its val_nll. Sorted by val_nll.
    """
    grid_job = copy.deepcopy(job)
    df_train, _, n_features = create_train_test_data(grid_job)

    # Split into train/val
    df_train, df_val = train_test_split(df_train, train_size=train_size, test_size=val_size,
                                        random_state=grid_job["seed"])

    x_cols = df_train.columns[df_train.columns.str.startswith("x")]
    X_train = df_train.loc[:, x_cols].to_numpy(dtype=np.float32)
    y_train = df_train["y"].to_numpy(dtype=np.float32)

    X_val = df_val.loc[:, x_cols].to_numpy(dtype=np.float32)
    y_val = df_val["y"].to_numpy(dtype=np.float32)

    # Normalize y_train (no need to normalize y_val, because predictions are denormalized 
    # and val_nll is based on denormalized predictions)
    y_mean = y_train.mean(axis=0)
    y_std = y_train.std(axis=0)
    y_train_norm = (y_train - y_mean) / y_std

    # Create parameter grid
    keys = list(param_grid.keys())
    values_product = list(itertools.product(*(param_grid[k] for k in keys)))
    n_trials = len(values_product)

    results = []
    best_val_nll = float("inf")
    best_combo = None

    print(f"[GridSearch] Trials: {n_trials} over keys {keys}")

    for i, vals in enumerate(values_product, start=1):
        # Seeding per Trial
        trial_job = copy.deepcopy(grid_job)
        set_global_seed(trial_job["seed"])

        # Update model_params with current grid parameters
        combo = dict(zip(keys, vals))
        trial_params = copy.deepcopy(trial_job["model_params"])
        trial_params.update(combo)
        trial_job["model_params"] = trial_params

        print(f"[{i:>3}/{n_trials}] model_params -> {trial_job['model_params']}")

        model = build_model(trial_job["model_name"], trial_job["model_params"], trial_job["seed"], n_features)

        model.fit(X_train, y_train_norm)

        # Validate
        _, _, _, _, val_nll = model.predict_with_uncertainties(
            X_test=X_val, y_test=y_val, y_mean=y_mean, y_std=y_std, test_interval=trial_job["test_interval"], train_interval=trial_job["train_interval"]
        )
        val_nll = float(val_nll.item())
        row = {**combo,
               "val_nll": val_nll}
        results.append(row)
        print(f"    -> val_nll={val_nll:.6f}")

        if val_nll < best_val_nll:
            best_val_nll = val_nll
            best_combo = combo

    results_df = pd.DataFrame(results).sort_values("val_nll", ascending=True).reset_index(drop=True)

    print("\n[Best]")
    print(best_combo, "-> val_nll=", best_val_nll)

    return results_df

# %% [markdown]
# ## Bayes by Backprop

# %%
bbb_params = {
    "prior_mean": 0.0,
    "n_mc_samples": 300,
    "mu_init_mean": 0.0,
    # grid search
    "prior_sigma": None,
    "kl_beta": None,
    "mu_init_std": None,
    "rho_init": None,
    "lr": None,
    "epochs": None,
    "batch_size": None
}

bbb_job = make_job(BASE_JOB, model_name="bbb", model_params=bbb_params)

results_df= grid_search(bbb_job, 
                        param_grid = {
                        "rho_init":   [-3.0, -4.0, -5.0],
                        "kl_beta":    [0.3, 0.6, 1.0],
                        "prior_sigma":[0.5, 1.0, 2.0],
                        "mu_init_std":[0.1, 0.2],
                        "lr": [0.001, 0.01],
                        "epochs": [100, 200],
                        "batch_size": [32, 64],
                        },
                        train_size=1000,
                        val_size=100
                        )
results_df
# Out:
# [GridSearch] Trials: 432 over keys ['rho_init', 'kl_beta', 'prior_sigma', 'mu_init_std', 'lr', 'epochs', 'batch_size']
# [  1/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.642607
# [  2/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.463337
# [  3/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.702063
# [  4/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.587266
# [  5/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.708456
# [  6/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.637151
# [  7/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.761316
# [  8/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.699805
# [  9/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.634353
# [ 10/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.462261
# [ 11/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.709609
# [ 12/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.569102
# [ 13/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.748125
# [ 14/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.564732
# [ 15/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.761580
# [ 16/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.654836
# [ 17/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.645659
# [ 18/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.465966
# [ 19/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.705931
# [ 20/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.592745
# [ 21/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.710898
# [ 22/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.638558
# [ 23/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.638507
# [ 24/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.736457
# [ 25/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.632305
# [ 26/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.449179
# [ 27/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.709182
# [ 28/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.571943
# [ 29/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.671139
# [ 30/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=0.830921
# [ 31/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.724411
# [ 32/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=nan
# [ 33/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.646479
# [ 34/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.467221
# [ 35/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.707772
# [ 36/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.594633
# [ 37/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=nan
# [ 38/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-0.419644
# [ 39/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=nan
# [ 40/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.3, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=nan
# [ 41/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.631406
# [ 42/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.458117
# [ 43/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.709737
# [ 44/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.572391
# [ 45/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.724545
# [ 46/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.188504
# [ 47/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.404884
# [ 48/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.3, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.621419
# [ 49/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.625843
# [ 50/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.413625
# [ 51/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.677891
# [ 52/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.498532
# [ 53/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.735211
# [ 54/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.422846
# [ 55/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.717353
# [ 56/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.564722
# [ 57/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.614412
# [ 58/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.398039
# [ 59/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.685923
# [ 60/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.493698
# [ 61/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.728551
# [ 62/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.283919
# [ 63/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.741540
# [ 64/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.615527
# [ 65/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.623565
# [ 66/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.405591
# [ 67/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.681455
# [ 68/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.511767
# [ 69/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.704639
# [ 70/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.462906
# [ 71/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.553138
# [ 72/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.572668
# [ 73/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.617932
# [ 74/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.408385
# [ 75/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.683975
# [ 76/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.510917
# [ 77/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.712421
# [ 78/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.448775
# [ 79/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.674451
# [ 80/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.554696
# [ 81/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.626117
# [ 82/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.406382
# [ 83/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.685510
# [ 84/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.511166
# [ 85/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=0.342049
# [ 86/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=nan
# [ 87/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=nan
# [ 88/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.6, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=nan
# [ 89/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.614196
# [ 90/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.409490
# [ 91/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.686558
# [ 92/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.517615
# [ 93/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.648584
# [ 94/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-1.662849
# [ 95/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.572495
# [ 96/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 0.6, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-1.489250
# [ 97/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.606749
# [ 98/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.352482
# [ 99/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.635940
# [100/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.395166
# [101/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.722598
# [102/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.179357
# [103/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.573779
# [104/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.350931
# [105/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.593781
# [106/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.350741
# [107/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.648268
# [108/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.394442
# [109/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.515642
# [110/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.129219
# [111/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.682960
# [112/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.340080
# [113/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.598696
# [114/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.364822
# [115/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.645258
# [116/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.425371
# [117/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.687406
# [118/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.139886
# [119/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.501656
# [120/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.368827
# [121/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.596368
# [122/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.349638
# [123/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.653698
# [124/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.427032
# [125/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -3.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.685406
# ...
#     -> val_nll=-2.692956
# [395/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.745590
# [396/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.720319
# [397/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.708881
# [398/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.279478
# [399/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.700071
# [400/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 0.5, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.162141
# [401/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -5.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.767123
# [402/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -5.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.735677
# [403/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -5.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.736261
# [404/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -5.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.705498
# [405/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.571950
# [406/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.165630
# [407/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.625498
# [408/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.480207
# [409/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.764616
# [410/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.693160
# [411/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.752255
# [412/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.720955
# [413/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.685697
# [414/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-1.664982
# [415/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.684340
# [416/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 1.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-1.965108
# [417/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -5.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.768669
# [418/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -5.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.734150
# [419/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -5.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.735818
# [420/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -5.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.720131
# [421/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=nan
# [422/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-1.625060
# [423/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=nan
# [424/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 1.0, 'mu_init_std': 0.1, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=nan
# [425/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.766011
# [426/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.698555
# [427/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.752150
# [428/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.723118
# [429/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.651217
# [430/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-1.274046
# [431/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.624724
# [432/432] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'prior_mean': 0.0, 'n_mc_samples': 300, 'mu_init_mean': 0.0, 'prior_sigma': 2.0, 'kl_beta': 1.0, 'mu_init_std': 0.2, 'rho_init': -5.0, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=nan
#
# [Best]
# {'rho_init': -5.0, 'kl_beta': 0.3, 'prior_sigma': 1.0, 'mu_init_std': 0.1, 'lr': 0.001, 'epochs': 100, 'batch_size': 32} -> val_nll= -2.7728042602539062
#      rho_init  kl_beta  prior_sigma  mu_init_std     lr  epochs  batch_size  \
# 0        -5.0      0.3          1.0          0.1  0.001     100          32
# 1        -5.0      0.3          0.5          0.1  0.001     100          32
# 2        -5.0      0.3          2.0          0.1  0.001     100          32
# 3        -5.0      0.6          2.0          0.1  0.001     100          32
# 4        -5.0      0.6          1.0          0.1  0.001     100          32
# ..        ...      ...          ...          ...    ...     ...         ...
# 427      -5.0      0.6          2.0          0.2  0.010     200          64
# 428      -5.0      1.0          2.0          0.1  0.010     100          32
# 429      -5.0      1.0          2.0          0.1  0.010     200          32
# 430      -5.0      1.0          2.0          0.1  0.010     200          64
# 431      -5.0      1.0          2.0          0.2  0.010     200          64
#
#       val_nll
# 0   -2.772804
# 1   -2.772165
# 2   -2.771491
# 3   -2.771479
# 4   -2.771319
# ..        ...
# 427       NaN
# 428       NaN
# 429       NaN
# 430       NaN
# 431       NaN
#
# [432 rows x 8 columns]

# %% [markdown]
# # Deep Ensemble

# %%
ensemble_params = {
    "n_members": 5,
    # grid search
    "weight_decay": None,
    "lr": None,
    "epochs": None,
    "batch_size": None
}

ensemble_job = make_job(BASE_JOB, model_name="ensemble", model_params=ensemble_params)

results_df= grid_search(ensemble_job, 
                        param_grid = {
                        "weight_decay": [1e-3, 5e-4, 1e-4],
                        "lr": [0.001, 0.01],
                        "epochs": [100, 200],
                        "batch_size": [32, 64],
                        },
                        train_size=1000,
                        val_size=100
                        )
results_df
# Out:
# [GridSearch] Trials: 24 over keys ['weight_decay', 'lr', 'epochs', 'batch_size']
# [  1/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.766798
# [  2/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.769192
# [  3/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.776574
# [  4/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.775837
# [  5/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.774021
# [  6/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.768651
# [  7/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.773914
# [  8/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.762038
# [  9/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.766972
# [ 10/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.768935
# [ 11/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.776955
# [ 12/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.775924
# [ 13/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.764767
# [ 14/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.759130
# [ 15/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.770320
# [ 16/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.763240
# [ 17/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.767479
# [ 18/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.769066
# [ 19/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.778323
# [ 20/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.777736
# [ 21/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.757943
# [ 22/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.763947
# [ 23/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.777561
# [ 24/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_members': 5, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.770328
#
# [Best]
# {'weight_decay': 0.0001, 'lr': 0.001, 'epochs': 200, 'batch_size': 32} -> val_nll= -2.778323173522949
#     weight_decay     lr  epochs  batch_size   val_nll
# 0         0.0001  0.001     200          32 -2.778323
# 1         0.0001  0.001     200          64 -2.777736
# 2         0.0001  0.010     200          32 -2.777561
# 3         0.0005  0.001     200          32 -2.776955
# 4         0.0010  0.001     200          32 -2.776574
# 5         0.0005  0.001     200          64 -2.775924
# 6         0.0010  0.001     200          64 -2.775837
# 7         0.0010  0.010     100          32 -2.774021
# 8         0.0010  0.010     200          32 -2.773914
# 9         0.0001  0.010     200          64 -2.770328
# 10        0.0005  0.010     200          32 -2.770320
# 11        0.0010  0.001     100          64 -2.769192
# 12        0.0001  0.001     100          64 -2.769066
# 13        0.0005  0.001     100          64 -2.768935
# 14        0.0010  0.010     100          64 -2.768651
# 15        0.0001  0.001     100          32 -2.767479
# 16        0.0005  0.001     100          32 -2.766972
# 17        0.0010  0.001     100          32 -2.766798
# 18        0.0005  0.010     100          32 -2.764767
# 19        0.0001  0.010     100          64 -2.763947
# 20        0.0005  0.010     200          64 -2.763240
# 21        0.0010  0.010     200          64 -2.762038
# 22        0.0005  0.010     100          64 -2.759130
# 23        0.0001  0.010     100          32 -2.757943

# %% [markdown]
# # MC Dropout

# %%
mcdropout_params = {
        'n_mc_samples': 300,
        # grid search
        'p_drop': None,
        'weight_decay': None,
        }

mcdropout_job = make_job(BASE_JOB, model_name="mcdropout", model_params=mcdropout_params)
print(mcdropout_job)

results_df= grid_search(mcdropout_job, 
                        param_grid = {
                        "weight_decay": [1e-3, 5e-4, 1e-4],
                        "p_drop": [0.05, 0.1, 0.2],
                        "lr": [0.001, 0.01],
                        "epochs": [100, 200],
                        "batch_size": [32, 64],
                        },
                        train_size=1000,
                        val_size=100
                        )
results_df
# Out:
# {'experiment_name': 'hyperparameter_tuning', 'model_runs': 1, 'seed': 42, 'function': ['f_cosine_hc2_1_feat', 'sigma_cubic_hc2_1_feat'], 'train_interval': [-4.0, 4.0], 'train_instances': 1100, 'train_repeats': 0, 'test_interval': [-6.0, 6.0], 'test_grid_length': 1000, 'test_add_points': None, 'model_name': 'mcdropout', 'model_params': {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': None, 'p_drop': None, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300}}
# [GridSearch] Trials: 72 over keys ['weight_decay', 'p_drop', 'lr', 'epochs', 'batch_size']
# [  1/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.761636
# [  2/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.761175
# [  3/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.763283
# [  4/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.769362
# [  5/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.734946
# [  6/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.741179
# [  7/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.766756
# [  8/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.729692
# [  9/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.745450
# [ 10/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.747662
# [ 11/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.760537
# [ 12/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.764513
# [ 13/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.747559
# [ 14/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.679928
# [ 15/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.743697
# [ 16/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.688971
# [ 17/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.720507
# [ 18/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.707250
# [ 19/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.743471
# [ 20/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.727115
# [ 21/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.697178
# [ 22/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.700402
# [ 23/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.642980
# [ 24/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.001, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.666556
# [ 25/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.761682
# [ 26/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.761211
# [ 27/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.763067
# [ 28/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.771851
# [ 29/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.758249
# [ 30/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.717254
# [ 31/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.765720
# [ 32/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.715546
# [ 33/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.744422
# [ 34/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.746907
# [ 35/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.768202
# [ 36/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.763681
# [ 37/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.749744
# [ 38/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.717403
# [ 39/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.718456
# [ 40/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.702206
# [ 41/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.719984
# [ 42/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.709026
# [ 43/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.746136
# [ 44/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.727371
# [ 45/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.708226
# [ 46/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.694912
# [ 47/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.678525
# [ 48/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0005, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.683452
# [ 49/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.761184
# [ 50/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.759924
# [ 51/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.761180
# [ 52/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.769096
# [ 53/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.730871
# [ 54/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.697888
# [ 55/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.753357
# [ 56/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.05, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.736970
# [ 57/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.746053
# [ 58/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.747150
# [ 59/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.771315
# [ 60/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.768712
# [ 61/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.727127
# [ 62/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.700908
# [ 63/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.727057
# [ 64/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.1, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.745592
# [ 65/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.722257
# [ 66/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.708848
# [ 67/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.746979
# [ 68/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.729271
# [ 69/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.704376
# [ 70/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.690916
# [ 71/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.704947
# [ 72/72] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0001, 'p_drop': 0.2, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'n_mc_samples': 300, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.701141
#
# [Best]
# {'weight_decay': 0.0005, 'p_drop': 0.05, 'lr': 0.001, 'epochs': 200, 'batch_size': 64} -> val_nll= -2.7718513011932373
#     weight_decay  p_drop     lr  epochs  batch_size   val_nll
# 0         0.0005    0.05  0.001     200          64 -2.771851
# 1         0.0001    0.10  0.001     200          32 -2.771315
# 2         0.0010    0.05  0.001     200          64 -2.769362
# 3         0.0001    0.05  0.001     200          64 -2.769096
# 4         0.0001    0.10  0.001     200          64 -2.768712
# ..           ...     ...    ...     ...         ...       ...
# 67        0.0005    0.20  0.010     200          64 -2.683452
# 68        0.0010    0.10  0.010     100          64 -2.679928
# 69        0.0005    0.20  0.010     200          32 -2.678525
# 70        0.0010    0.20  0.010     200          64 -2.666556
# 71        0.0010    0.20  0.010     200          32 -2.642980
#
# [72 rows x 6 columns]

# %% [markdown]
# # Deep Evidential Regression

# %%
evidential_params = {
        # grid search
        'coeff': None,
        'lr': None,
        'epochs': None,
        'batch_size': None
        }

evidential_job = make_job(BASE_JOB, model_name="evidential", model_params=evidential_params)

results_df= grid_search(evidential_job, 
                        param_grid = {
                        "coeff": [0.005, 0.01, 0.05],
                        "lr": [0.001, 0.01],
                        "epochs": [100, 200],
                        "batch_size": [32, 64],
                        },
                        train_size=1000,
                        val_size=100
                        )
results_df
# Out:
# [GridSearch] Trials: 24 over keys ['coeff', 'lr', 'epochs', 'batch_size']
# [  1/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.005, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.781621
# [  2/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.005, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.701558
# [  3/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.005, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.774025
# [  4/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.005, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.778984
# [  5/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.005, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.743682
# [  6/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.005, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.778233
# [  7/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.005, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.779406
# [  8/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.005, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.769257
# [  9/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.01, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.777282
# [ 10/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.01, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.703454
# [ 11/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.01, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.774777
# [ 12/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.01, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.780140
# [ 13/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.01, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.727681
# [ 14/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.01, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.769396
# [ 15/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.01, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.780552
# [ 16/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.01, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.771881
# [ 17/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.05, 'lr': 0.001, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.767039
# [ 18/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.05, 'lr': 0.001, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.681125
# [ 19/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.05, 'lr': 0.001, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.760572
# [ 20/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.05, 'lr': 0.001, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.767276
# [ 21/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.05, 'lr': 0.01, 'epochs': 100, 'batch_size': 32}
#     -> val_nll=-2.738938
# [ 22/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.05, 'lr': 0.01, 'epochs': 100, 'batch_size': 64}
#     -> val_nll=-2.753072
# [ 23/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.05, 'lr': 0.01, 'epochs': 200, 'batch_size': 32}
#     -> val_nll=-2.773245
# [ 24/24] model_params -> {'hidden_features': [64, 64], 'activations': ['relu', 'relu'], 'weight_decay': 0.0, 'p_drop': 0.0, 'shuffle': True, 'device': 'cpu', 'target_dim': 1, 'coeff': 0.05, 'lr': 0.01, 'epochs': 200, 'batch_size': 64}
#     -> val_nll=-2.748253
#
# [Best]
# {'coeff': 0.005, 'lr': 0.001, 'epochs': 100, 'batch_size': 32} -> val_nll= -2.781620502471924
#     coeff     lr  epochs  batch_size   val_nll
# 0   0.005  0.001     100          32 -2.781621
# 1   0.010  0.010     200          32 -2.780552
# 2   0.010  0.001     200          64 -2.780140
# 3   0.005  0.010     200          32 -2.779406
# 4   0.005  0.001     200          64 -2.778984
# 5   0.005  0.010     100          64 -2.778233
# 6   0.010  0.001     100          32 -2.777282
# 7   0.010  0.001     200          32 -2.774777
# 8   0.005  0.001     200          32 -2.774025
# 9   0.050  0.010     200          32 -2.773245
# 10  0.010  0.010     200          64 -2.771881
# 11  0.010  0.010     100          64 -2.769396
# 12  0.005  0.010     200          64 -2.769257
# 13  0.050  0.001     200          64 -2.767276
# 14  0.050  0.001     100          32 -2.767039
# 15  0.050  0.001     200          32 -2.760572
# 16  0.050  0.010     100          64 -2.753072
# 17  0.050  0.010     200          64 -2.748253
# 18  0.005  0.010     100          32 -2.743682
# 19  0.050  0.010     100          32 -2.738938
# 20  0.010  0.010     100          32 -2.727681
# 21  0.010  0.001     100          64 -2.703454
# 22  0.005  0.001     100          64 -2.701558
# 23  0.050  0.001     100          64 -2.681125
